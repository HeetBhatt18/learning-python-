# %%
sets = {10,20,30}

# %%
sets
# Out:
# {10, 20, 30}

# %%
sets1 ={10,20,30,40,(1,2,3,4),50}

# %%
sets1 # The tuple is not stored at its index where we have created
# Out:
# {(1, 2, 3, 4), 10, 20, 30, 40, 50}

# %%
sets = {10,20,10}

# %%
sets # Here the duplicate is removed
# Out:
# {10, 20}

# %%
sets = {10,20,30}

# %%
sets
# Out:
# {10, 20, 30}
