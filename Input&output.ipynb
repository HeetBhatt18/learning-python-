# %% [markdown]
# # **Input and Output function.**
#
# ###  It is used take input from the user and output for returning some values.
#
# ### By default python will read the input in String.
#
# ### Output is just the print function to return some value to the user.

# %% [markdown]
# # **Input Function**

# %%
Num = int(input("Enter a number:"))
print(Num)
# Out:
# 10

# %%
Num_1 = int(input("Enter first number: "))
Num_2 = int(input("Enter second number: "))
sum = Num_1 + Num_2
print("The total is:",sum)
# Out:
# The total is: 30

# %%
Char_1 = str(input("Enter first name:"))
Char_2 = str(input("Enter middle name:"))
Char_3 = str(input("Enter last name:"))
print(Char_1+" "+Char_2+" "+Char_3)
# Out:
# Heet D Bhatt
