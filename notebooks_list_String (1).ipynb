# %%
str = ('Hello')

# %%
str
# Out:
# 'Hello'

# %%
string = input("Enter a number :")
# Out:
# Enter a number : Hello

# %%
A,B = input("Enter the number").split()  # Here we use split function to store single value in multiple variable at single line.
# Out:
# Enter the number Hello world

# %%
A
# Out:
# 'Hello'

# %%
B
# Out:
# 'world'

# %%
para = """ Some days just feel softer than others. The sunlight hits differently, the air feels calmer, and you carry a quiet confidence without even trying. It’s not about being loud or standing out — it’s about feeling comfortable in your own skin. Sometimes the simplest moments, the smallest smiles, and the most effortless looks say the most. And that peaceful kind of energy?"""
# (""" """) it is used to store multiline string.

# %%
para
# Out:
# ' Some days just feel softer than others. The sunlight hits differently, the air feels calmer, and you carry a quiet confidence without even trying. It’s not about being loud or standing out — it’s about feeling comfortable in your own skin. Sometimes the simplest moments, the smallest smiles, and the most effortless looks say the most. And that peaceful kind of energy?'

# %%
B =[]
B=a
for i in range(5):
    a = int(input("Enter the number"))
# Out:
# Enter the number 10
# Enter the number 20
# Enter the number 30
# Enter the number 40
# Enter the number 50

# %%
a
# Out:
# 50

# %%
B
# Out:
# 50

# %%
Concatination = ("Hello.")
add = 10
Final = Concatination + "add"

# %%
Final
# Out:
# 'Hello.add'

# %%
Name = ()
Chara = Name

for i in range(5):
    Chara = input("Enter character")
# Out:
# Enter character M
# Enter character O
# Enter character H
# Enter character I
# Enter character T

# %%
Chara
# Out:
# 'T'
