# %%
sets1 = {10,20,30,40,50,"Hello"}

# %%
sets1
# Out:
# {10, 20, 30, 40, 50, 'Hello'}

# %%
'Hello' in sets1 # Used to check that is "Hello" is present in the list or not. If present then return (True) $ if not return (False).
# Out:
# True

# %%
H = {10,20,30,40,20,10}

# %%
H # Here the duplicate values are removed. so no duplicate values are allowed
# Out:
# {10, 20, 30, 40}

# %%
cs_course = {"Arts", "Science" , "Maths"}

# %%
cs_course
# Out:
# {'Arts', 'Maths', 'Science'}

# %%
cs_course1 = {"avitation" , "Computer Network" , "Maths"}

# %%
cs_course1
# Out:
# {'Computer Network', 'Maths', 'avitation'}

# %%
cs_course.intersection (cs_course1) # Intersection command is used to print out the comman values from 2 lists.
# Out:
# {'Maths'}

# %%
cs_course1.difference (cs_course) # Difference command is used to print out the different values from the sets.
# Out:
# {'Computer Network', 'avitation'}

# %%
cs_course.difference (cs_course1)
# Out:
# {'Arts', 'Science'}

# %%
cs_course.union (cs_course1) #it is used to combine 2 sets in 1.
# Out:
# {'Arts', 'Computer Network', 'Maths', 'Science', 'avitation'}

# %%
Sets10 = {} # we can also create the Empty set

# %%
Sets10
# Out:
# {}

# %%
# Set is an unordered collection of elements. Written in curly ({}) braces.
