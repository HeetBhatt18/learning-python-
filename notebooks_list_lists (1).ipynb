# %%
list = [10,20,30,40,50]

# %%
list
# Out:
# [10, 20, 30, 40, 50]

# %%
list1 = ["hello",10 ,10.5 , "world" , True]

# %%
list1
# Out:
# ['hello', 10, 10.5, 'world', True]

# %%
list[0:3]
# Out:
# [10, 20, 30]

# %%
list1[0:6]
# Out:
# ['hello', 10, 10.5, 'world', True]

# %%
list1[:]
# Out:
# ['hello', 10, 10.5, 'world', True]

# %%
list[1:4]
# Out:
# [20, 30, 40]

# %%
list.append(60)

# %%
list
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1.insert(2,"heet")

# %%
list1
# Out:
# ['hello', 10, 'heet', 10.5, 'world', True]

# %%
list.insert(5,60)

# %%
list
# Out:
# [10, 20, 30, 40, 50, 60, 60]

# %%
list.remove(60)

# %%
list
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list.pop()
# Out:
# 60

# %%
list
# Out:
# [10, 20, 30, 40, 50]

# %%
list.clear()

# %%
list
# Out:
# []

# %%
list.append(10)

# %%
list
# Out:
# [10]

# %%
list.append(20)

# %%
list
# Out:
# [10, 20]

# %%
list.insert(2,30)

# %%
list
# Out:
# [10, 20, 30]

# %%
list[:4]
# Out:
# [10, 20, 30]

# %%
list1.pop()
# Out:
# True

# %%
list1
# Out:
# ['hello', 10, 'heet', 10.5, 'world']

# %%
list1.insert(3,"my name is")

# %%
list1
# Out:
# ['hello', 10, 'heet', 'my name is', 10.5, 'world']

# %%
list1.append(20)

# %%
list1
# Out:
# ['hello', 10, 'heet', 'my name is', 10.5, 'world', 20]

# %%
list1.pop()
# Out:
# 20

# %%
list1.append(10.5)

# %%
list1
# Out:
# ['hello', 10, 'heet', 'my name is', 10.5, 'world', 10.5]

# %%
list1.count(10.5)
# Out:
# 2

# %%
list1.reverse()

# %%
list1
# Out:
# [10.5, 'world', 10.5, 'my name is', 'heet', 10, 'hello']

# %%
list1.copy()
# Out:
# [10.5, 'world', 10.5, 'my name is', 'heet', 10, 'hello']

# %%
extend = [20,"hello","h", "e" , "e" ,"t"]

# %%
extend1 = [20.5 , True]

# %%
extend.extend(extend1)

# %%
extend
# Out:
# [20, 'hello', 'h', 'e', 'e', 't', 20.5, True]

# %%
extend[0:9:2]
# Out:
# [20, 'h', 'e', 20.5]

# %%
list2 = (10,20,30,[1,2,3],40)

# %%
list2[4]
# Out:
# 40
