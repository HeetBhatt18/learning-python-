# %%
Students = {'Name' : 'John' , 'Age' : 21 , 'Courses' : ['C','C++']} 
# Syntax to create dictonary 
# dic_name = {Key : elements
#             Key1 : elements} to add multiple elements we use square ([]) brackets.

# %%
Students
# Out:
# {'Name': 'John', 'Age': 21, 'Courses': ['C', 'C++']}

# %%
Students ['Name'] # to print out single key value
# Out:
# 'John'

# %%
Students ['Age']
# Out:
# 21

# %%
Students ['Courses']
# Out:
# ['C', 'C++']

# %%
Students.update({'Name' : 'Jane'}) # Used to update new values in place of old one

# %%
Students
# Out:
# {'Name': 'Jane', 'Age': 21, 'Courses': ['C', 'C++']}

# %%
del Students['Age'] # Used to Delete the key

# %%
Students
# Out:
# {'Name': 'Jane', 'Courses': ['C', 'C++']}

# %%
Students.items() # We can check both key and elements using items function.
# Out:
# dict_items([('Name', 'Jane'), ('Courses', ['C', 'C++'])])
