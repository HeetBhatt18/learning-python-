# %%
tuple = (10,20,30,40)

# %%
tuple
# Out:
# (10, 20, 30, 40)

# %%
tuple[0:3]
# Out:
# (10, 20, 30)

# %%
tuple[3]
# Out:
# 40

# %%
tuple1 = (10,20,30,[1,2,3],40,50)

# %%
tuple1[3]
# Out:
# [1, 2, 3]

# %%
tuple1[:-1]
# Out:
# (10, 20, 30, [1, 2, 3], 40)

# %%
tuple1[0:6:2]
# Out:
# (10, 30, 40)

# %%
tuple1
# Out:
# (10, 20, 30, [1, 2, 3], 40, 50)
